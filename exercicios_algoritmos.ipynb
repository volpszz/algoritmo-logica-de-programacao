# %% [markdown]
# <a href="https://colab.research.google.com/github/volpszz/algoritmo-logica-de-programacao/blob/main/exercicios_algoritmos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("adicao")

a = float(input("Insira um numero: "))
b = float(input("Insira um numero: "))

soma = a + b

print(soma)
# Out:
# adicao
# Insira um numero: 2
# Insira um numero: 2
# 4.0

# %%
print("subtracao")

a = float(input("Insira um numero: "))
b = float(input("Insira um numero: "))

subtracao = a - b

print(subtracao)
# Out:
# subtracao
# Insira um numero: 2
# Insira um numero: 2
# 0.0

# %%
print("multiplicacao")

a = float(input("Insira um numero: "))
b = float(input("Insira um numero: "))

multiplicacao = a * b

print(multiplicacao)
# Out:
# multiplicacao
# Insira um numero: 2
# Insira um numero: 2
# 4.0

# %%
print("divisao")

a = float(input("Insira um numero: "))
b = float(input("Insira um numero: "))

divisao = a / b

print(divisao)
# Out:
# divisao
# Insira um numero: 2
# Insira um numero: 2
# 1.0

# %%
print("multiplicacao")

a = float(input("Insira um numero: "))
b = float(input("Insira um numero: "))

multiplicacao = a * b

print(multiplicacao)

# %%
a = float(input("Dobro e triplo \nInsira um numero: "))
print(f"\nDobro = {a * 2}")
print(f"\nTriplo = {a * 3}")

# %%
a = float(input("Antecessor e sucessor \nInsira um numero: "))
print(f"\nAntecessor = {a - 1}")
print(f"\nSucessor = {a + 1}")
# Out:
# Antecessor e sucessor
# Insira um numero: 2
#
# Dobro = 1.0
#
# Triplo = 3.0

# %%
base = float(input("Perimetro do retangulo \n Insira a base: "))
altura = float(input("\nInsira a altura: "))
print(f"Perimetro do rentagulo = {2 * (base + altura)}")
# Out:
# Perimetro do retangulo
#  Insira a base: 2
# Perimetro do retangulo
#  Insira a altura: 2
# Perimetro do rentagulo = 8.0

# %%
base = float(input("Perimetro do retangulo \n Insira a base: "))
altura = float(input("\nInsira a altura: "))
print(f"Perimetro do rentagulo = {2 * (base + altura)}")

# %%
base = float(input("Area do retangulo \n Insira a base: "))
altura = float(input("\nInsira a altura: "))
print(f"Area do rentagulo = {base * altura}")
# Out:
# Area do rentagulo = 4.0

# %%
num = int(input("Positivo, Negativo ou zero! \n Insira um numero: "))

if num > 0:
  print("Positivo!")

elif num < 0:
  print("Negativo!")

else:
  print("Zero!")
# Out:
# Positivo, Negativo ou zero!
#  Insira um numero: 5
# Positivo!

# %%
num = int(input("Par ou impar \n Insira um numero: "))

if num == 0:
  print("Zero!")

elif num % 2 == 0:
  print("Par!")

elif num % 2 != 0:
  print("Impar!")

else:
  print("Insira um numero valido!")
# Out:
# Par ou impar
#  Insira um numero: 0
# Zero!

# %%
num = int(input("Maior entre dois \n Insira o primeiro numero: "))

num2 = int(input("\n Insira o segundo numero: "))

if num > num2:
  print("O(1) numero é maior")

elif num2 > num:
  print("O(2) numero é maior")

else:
  print("Os numeroes sao iguais")
# Out:
# Maior entre dois
#  Insira o primeiro numero: 90
#
#  Insira o segundo numero: 90
# Impar!

# %%
num = int(input("Maior entre tres \n Insira o primeiro numero: "))

num2 = int(input("\n Insira o segundo numero: "))

num3 = int(input("\n Insira o terceiro numero: "))

if num > num2 and num > num3:
  print("O(1) numero é maior")

elif num2 > num and num2 > num3:
  print("O(2) numero é maior")

elif num3 > num and num3 > num2:
  print("O(3) numero é maior")

else:
  print("Os numeros sao iguais!")
# Out:
# Maior entre dois
#  Insira o primeiro numero: 40
#
#  Insira o segundo numero: 50
#
#  Insira o terceiro numero: 60
# O(3) numero é maior
